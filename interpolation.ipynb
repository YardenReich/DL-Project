# %%
#@title Connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/VQGAN-pytorch
# Out:
# /content/drive/MyDrive/VQGAN-pytorch

# %%
import interpolation
import argparse

# %%
#@title Parameters { run: "auto", display-mode: "form" }
#@markdown ### options:

#@markdown Video name:
video_name = "video" #@param {type:"string"}

#@markdown First image path:
csv_path = "data/data.csv" #@param {type:"string"}

#@markdown First image path:
image1_path = "images/image1.jpg" #@param {type:"string"}

#@markdown Second image path:
image2_path = "images/image2.jpg" #@param {type:"string"}

#@markdown Model path:
model_path = "checkpoints/half_and_half/epoch_48/model.pt" #@param {type:"string"}

#@markdown Number of codebook vectors:
codebook_vectors = 256 #@param {type:"integer"}

#@markdown Device:
device = "cpu" #@param {type:"string"}


#@markdown ### Other Options

#@markdown Type of interpolation:
inter_type = 0 #@param [0, 1, 2]

#@markdown Country of the data:
#@markdown *First letter upper case*
country = "Israel" #@param {type:"string"}

#@markdown Frames per second:
#@markdown *min:10 max:60*
fps = 10 #@param {type:"integer"}

#@markdown Should the video be saved:
save_video = True #@param {type:"boolean"}

#@markdown Store the images
save_images = False #@param {type:"boolean"}

# %%
#@title Parse args

args = argparse.Namespace(
    csv_path = csv_path,
    file_name = video_name,
    image1_path = image1_path,
    image2_path = image2_path,
    model_path = model_path,
    device = device,
    fps = fps,
    num_codebook_vectors = codebook_vectors,
    image_size = 256,
    latent_dim = 256,
    beta = 0.25,
    image_channels = 3,
    type_of_interpolation = inter_type,
    country = country,
    create_video = save_video,
    save_images = save_images,
)

# %%
#@title Run Interpolation
interpolation.run_interpolation(args)
# Out:
#   3%|▎         | 4/118 [00:23<11:19,  5.96s/it]
